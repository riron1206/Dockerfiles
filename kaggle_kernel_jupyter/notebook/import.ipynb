# %%
# !pwd
import sys
sys.executable
# Out:
# /81908/jupyter_notebook/Dockerfiles/kaggle_kernel_jupyter/notebook
# '/opt/conda/bin/python'

# %%
# !env
# Out:
# MKL_THREADING_LAYER=GNU
# MPLBACKEND=agg
# HOSTNAME=5e6a2bfe3f4c
# LD_LIBRARY_PATH=/opt/conda/lib
# HOME=/root
# TESSERACT_PATH=/usr/bin/tesseract
# PAGER=cat
# TERM=xterm-color
# PATH=/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin
# LANG=C.UTF-8
# PYTHONUSERBASE=/root/.local
# GIT_PAGER=cat
# LC_ALL=C.UTF-8
# PROJ_LIB=/opt/conda/share/proj
# CLICOLOR=1
# PWD=/81908/jupyter_notebook/Dockerfiles/kaggle_kernel_jupyter/notebook
# JPY_PARENT_PID=6
# PYTHONPATH=:/opt/facets/facets_overview/python/

# %%
import numpy as np
import pandas as pd
import cv2
import sklearn
import lightgbm
import torch
import optuna
import keras
import tensorflow as tf

# pipで追加したパッケージ
import dash 
#import mlflow
#import pyspark
#from networks import Inpaint_Color_Net, Inpaint_Depth_Net, Inpaint_Edge_Net
#import pyopengl
#import MeCab
#import fancyimpute

# %%
pip list
# Out:
# Package                            Version             Location
# ---------------------------------- ------------------- --------------
# absl-py                            0.9.0
# affine                             2.3.0
# aiohttp                            3.6.2
# alabaster                          0.7.12
# albumentations                     0.4.5
# alembic                            1.4.2
# allennlp                           0.9.0
# altair                             4.0.1
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.12
# anaconda-project                   0.8.3
# annoy                              1.16.3
# appdirs                            1.4.3
# argh                               0.26.2
# arrow                              0.15.5
# arviz                              0.7.0
# asn1crypto                         1.3.0
# astor                              0.8.1
# astroid                            2.3.3
# ...

# %%
conda list
# Out:
# # packages in environment at /opt/conda:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0                    py36_0
# _libgcc_mutex             0.1                        main
# absl-py                   0.9.0                    pypi_0    pypi
# affine                    2.3.0                    pypi_0    pypi
# aiohttp                   3.6.2                    pypi_0    pypi
# alabaster                 0.7.12                     py_0
# albumentations            0.4.5                    pypi_0    pypi
# alembic                   1.4.2                    pypi_0    pypi
# allennlp                  0.9.0                    pypi_0    pypi
# altair                    4.0.1                    pypi_0    pypi
# anaconda-client           1.7.2                    py36_0
# anaconda-navigator        1.9.12                   py36_1
# anaconda-project          0.8.4                      py_0
# ...
